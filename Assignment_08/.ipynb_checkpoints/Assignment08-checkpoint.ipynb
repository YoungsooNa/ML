# %%
import matplotlib.pyplot as plt
import numpy as np


file_data   = "mnist_test.csv"
handle_file = open(file_data, "r")
data        = handle_file.readlines()
handle_file.close()

size_row    = 28    # height of the image
size_col    = 28    # width of the image

num_image   = len(data)
count       = 0     # count for the number of images

#
# make a matrix each column of which represents an images in a vector form 
#
list_image  = np.empty((size_row * size_col, num_image), dtype=float)
list_label  = np.empty(num_image, dtype=int)

for line in data:

    line_data   = line.split(',')
    label       = line_data[0]
    im_vector   = np.asfarray(line_data[1:])

    list_label[count]       = label
    list_image[:, count]    = im_vector    

    count += 1

# 
# plot first 100 images out of 10,000 with their labels
# 
lis
f1 = plt.figure(1)

indexs = [[] for x in range(10)]

for i in range(200):
    if len(indexs[list_label[i]]) < 10:
        indexs[list_label[i]].append(i)
    
    
for i in range(100):
    label       = i % 10
    index       = int(i / 10)
    im_vector   = list_image[:, indexs[label][index]]
    im_matrix   = im_vector.reshape((size_row, size_col))

    plt.subplot(10, 10, i+1)
    if i < 10:
        plt.title(i)
    plt.imshow(im_matrix, cmap='Greys', interpolation='None')

    frame   = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

plt.show()

# %%
average_image = [[ 0 for y in range(28*28)] for x in range(10)]
count_added = [0 for x in range(10)]

for i in range(10000):
    count_added[list_label[i]] += 1
    for index in range(28*28):
        average_image[list_label[i]][index] += list_image[index, i]

# %%
ave_image = np.asarray(average_image)
for k in range(10):
    ave_image[k] /= count_added[k]

# %%
fig, axs = plt.subplots(2, 5)

for i in range(10):
    label       = i % 10
    index       = int(i / 10)
    im_vector   = ave_image[i]
    im_matrix   = im_vector.reshape((size_row, size_col))

    plt.subplot(2, 5, i+1)
    plt.title(i)
    plt.imshow(im_matrix, cmap='Greys', interpolation='None')

    frame   = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

# %%
np.random.seed(10)
seta = np.random.normal(0, 1, 28*28)

# %%
plt.hist(seta, density=False)
# Out:
# (array([  3.,   5.,  40.,  92., 154., 205., 149.,  98.,  22.,  16.]),
#  array([-3.20440134, -2.61597018, -2.02753901, -1.43910785, -0.85067668,
#         -0.26224552,  0.32618565,  0.91461681,  1.50304798,  2.09147914,
#          2.67991031]),
#  <a list of 10 Patch objects>)

# %%
result = []
for i in range(10000):
    Z = np.dot(list_image[:, i] , seta)
    A = 1/(1+np.exp(-Z))
    result.append(A)

# %%
average_A= [0 for x in range(10)]
for i in range(10000):
    average_A[list_label[i]] += result[i]

ave_A = np.asarray(average_A)
for k in range(10):
    ave_A[k] /= count_added[k]

# %%
for i in range(10):
    print(f"Label {i}  = { ave_A[i]}")
# Out:
# Label 0  = 0.31786157586866054
# Label 1  = 0.7836395712749112
# Label 2  = 0.6133999206831462
# Label 3  = 0.4781620789214107
# Label 4  = 0.18773589601416746
# Label 5  = 0.42604445230447313
# Label 6  = 0.4711866242961187
# Label 7  = 0.142998661066467
# Label 8  = 0.4978711558295338
# Label 9  = 0.10892142438603516
